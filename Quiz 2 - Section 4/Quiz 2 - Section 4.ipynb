# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 2 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here

print("Samantha Lim")

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:
print("I will abide by Emory's code of conduct")

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", and "pandas"

# %%
# Write your answer here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = "5">
#
# Import the dataset "data_quiz/fifa23_players_basic.csv"
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting

# %%
# Write your own code
fifa23 = pd.read_csv('data_quiz/fifa23_players_basic.csv')
display(fifa23)
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
#       Positions Played Best Position          Nationality  \
# 0                   RW           CAM            Argentina
# 1                CF,ST            CF               France
# 2                   ST            ST               Poland
# 3               CM,CAM            CM              Belgium
# 4                ST,LW            ST               France
# ...                ...           ...                  ...
# 18534            ST,RM           CAM  Republic of Ireland
# 18535              CDM           CDM             China PR
# 18536               CM            RM     Northern Ireland
# 18537               CB            CB  Republic of Ireland
# 18538               LB            LB                India
#
#                                              Image Link  Age  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                 ...  ...  ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png   21  ...
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png   18  ...
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png   25  ...
#
#        Preferred Foot  Weak Foot Rating  Skill Moves  \
# 0                Left                 4            4
# 1               Right                 4            4
# 2               Right                 4            4
# 3               Right                 5            4
# 4               Right                 4            5
# ...               ...               ...          ...
# 18534           Right                 3            2
# 18535           Right                 3            2
# 18536           Right                 3            2
# 18537           Right                 3            2
# 18538            Left                 3            2
#
#        International Reputation National Team Name  \
# 0                             5          Argentina
# 1                             4             France
# 2                             5             Poland
# 3                             4            Belgium
# 4                             4             France
# ...                         ...                ...
# 18534                         1                  -
# 18535                         1                  -
# 18536                         1                  -
# 18537                         1                  -
# 18538                         1                  -
#
#                   National Team Image Link  National Team Position  \
# 0      https://cdn.sofifa.net/flags/ar.png                      RW
# 1      https://cdn.sofifa.net/flags/fr.png                      ST
# 2      https://cdn.sofifa.net/flags/pl.png                      ST
# 3      https://cdn.sofifa.net/flags/be.png                      RF
# 4      https://cdn.sofifa.net/flags/fr.png                      ST
# ...                                    ...                     ...
# 18534                                    -                       -
# 18535                                    -                       -
# 18536                                    -                       -
# 18537                                    -                       -
# 18538                                    -                       -
#
#       National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 0                              10                 Low                 Low
# 1                              19              Medium              Medium
# 2                               9                High              Medium
# 3                               7                High                High
# 4                              10                High                 Low
# ...                           ...                 ...                 ...
# 18534                           -              Medium              Medium
# 18535                           -              Medium              Medium
# 18536                           -                High              Medium
# 18537                           -              Medium              Medium
# 18538                           -              Medium              Medium
#
# [18539 rows x 32 columns]

# %% [markdown]
# <font size = "5">
#
# (a) Create a function and apply it to a column <br>
#
# <font size = "3">
#
# Step 1:
# - Define a function with a parameter "year"
# - If "year < 2016", status = "Joined before 2016"
# - If "height >= 2016", status = "Joined on 2016 or after"
# - The function returns "status"
#
# Step 2:
# - Extract the column "Joined On" in the dataset <br>
# (be carefeful to write the "J" and "O" capitalized)
# - Create a new variable called "joined_after2016" <br>
# to assign each player to the correct age bracket
#
# HINT: Use the ".apply()" function

# %%
# Write your own code
def fn_age(year):
    if "year < 2016":
        status = "Joined before 2016"
    elif "year >= 2016":
        status = "Joined on 2016 or after"
    return(status)

display(fifa23[["Joined On"]])
joined_after2016 = fifa23.apply(fn_age)
# Out:
#        Joined On
# 0           2021
# 1           2009
# 2           2022
# 3           2015
# 4           2018
# ...          ...
# 18534       2018
# 18535       2021
# 18536       2022
# 18537       2022
# 18538       2020
#
# [18539 rows x 1 columns]

# %% [markdown]
# <font size = "5">
#
# (b) Use queries + global variables
#
# <font size = "3">
#
# - Compute the mean of the column "Height(in cm)" <br>
# and store it as a variable
# - Subset the players whose value is above the mean value <br>
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# Reference the column as ``` `Height(in cm)`    ``` inside .query()

# %%
# Write your own code

mean_height = fifa23["Height(in cm)"].mean()
fifa23.query("`Height(in cm)` >= @mean_height")
# Out:
#               Known As           Full Name  Overall  Potential  \
# 1           K. Benzema       Karim Benzema       91         91
# 2       R. Lewandowski  Robert Lewandowski       91         91
# 4            K. Mbappé       Kylian Mbappé       91         95
# 6          T. Courtois    Thibaut Courtois       90         91
# 7             M. Neuer        Manuel Neuer       90         90
# ...                ...                 ...      ...        ...
# 18520          N. Deka         Nikhil Deka       48         61
# 18521         V. Yadav        Vishal Yadav       48         62
# 18524       A. Brînzea      Andreș Brînzea       48         72
# 18525  J. Russell-Rowe  Jacen Russell-Rowe       48         65
# 18528        Zhang Yue           Yue Zhang       48         56
#
#        Value(in Euro) Positions Played Best Position Nationality  \
# 1            64000000            CF,ST            CF      France
# 2            84000000               ST            ST      Poland
# 4           190500000            ST,LW            ST      France
# 6            90000000               GK            GK     Belgium
# 7            13500000               GK            GK     Germany
# ...               ...              ...           ...         ...
# 18520          100000               GK            GK       India
# 18521          100000               GK            GK       India
# 18524          130000               GK            GK     Romania
# 18525          120000               ST           CAM      Canada
# 18528          110000               RM            LM    China PR
#
#                                              Image Link  Age  ...  \
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# 6      https://cdn.sofifa.net/players/192/119/23_60.png   30  ...
# 7      https://cdn.sofifa.net/players/167/495/23_60.png   36  ...
# ...                                                 ...  ...  ...
# 18520  https://cdn.sofifa.net/players/261/423/23_60.png   19  ...
# 18521  https://cdn.sofifa.net/players/259/488/23_60.png   20  ...
# 18524  https://cdn.sofifa.net/players/271/179/23_60.png   16  ...
# 18525  https://cdn.sofifa.net/players/269/923/23_60.png   19  ...
# 18528  https://cdn.sofifa.net/players/268/922/23_60.png   22  ...
#
#        Preferred Foot  Weak Foot Rating  Skill Moves  \
# 1               Right                 4            4
# 2               Right                 4            4
# 4               Right                 4            5
# 6                Left                 3            1
# 7               Right                 4            1
# ...               ...               ...          ...
# 18520           Right                 3            1
# 18521           Right                 3            1
# 18524           Right                 2            1
# 18525           Right                 3            2
# 18528            Left                 2            2
#
#        International Reputation National Team Name  \
# 1                             4             France
# 2                             5             Poland
# 4                             4             France
# 6                             4            Belgium
# 7                             5            Germany
# ...                         ...                ...
# 18520                         1                  -
# 18521                         1                  -
# 18524                         1                  -
# 18525                         1                  -
# 18528                         1                  -
#
#                   National Team Image Link  National Team Position  \
# 1      https://cdn.sofifa.net/flags/fr.png                      ST
# 2      https://cdn.sofifa.net/flags/pl.png                      ST
# 4      https://cdn.sofifa.net/flags/fr.png                      ST
# 6      https://cdn.sofifa.net/flags/be.png                      GK
# 7      https://cdn.sofifa.net/flags/de.png                      GK
# ...                                    ...                     ...
# 18520                                    -                       -
# 18521                                    -                       -
# 18524  https://cdn.sofifa.net/flags/ro.png                       -
# 18525  https://cdn.sofifa.net/flags/ca.png                       -
# 18528                                    -                       -
#
#       National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 1                              19              Medium              Medium
# 2                               9                High              Medium
# 4                              10                High                 Low
# 6                               1              Medium              Medium
# 7                               1              Medium              Medium
# ...                           ...                 ...                 ...
# 18520                           -              Medium              Medium
# 18521                           -              Medium              Medium
# 18524                           -              Medium              Medium
# 18525                           -              Medium              Medium
# 18528                           -              Medium              Medium
#
# [9352 rows x 32 columns]

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Use ".sort_values()" to order the "Value(in Euro)" column <br>
# from largest to smaller
# - Get a subset with the 5 players with the highest monetary valuation

# %%
# Write your own code
value_descending = fifa23.sort_values(by="Value(in Euro)", ascending = False)
value_descending.iloc[0:5,:]
# Out:
#       Known As             Full Name  Overall  Potential  Value(in Euro)  \
# 4    K. Mbappé         Kylian Mbappé       91         95       190500000
# 21  E. Haaland        Erling Haaland       88         94       148000000
# 42  F. de Jong       Frenkie de Jong       87         92       116500000
# 82       Pedri  Pedro González López       85         93       116000000
# 5     M. Salah         Mohamed Salah       90         90       115500000
#
#    Positions Played Best Position  Nationality  \
# 4             ST,LW            ST       France
# 21               ST            ST       Norway
# 42               CM            CM  Netherlands
# 82               CM            CM        Spain
# 5                RW            RW        Egypt
#
#                                           Image Link  Age  ...  \
# 4   https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# 21  https://cdn.sofifa.net/players/239/085/23_60.png   21  ...
# 42  https://cdn.sofifa.net/players/228/702/23_60.png   25  ...
# 82  https://cdn.sofifa.net/players/251/854/23_60.png   19  ...
# 5   https://cdn.sofifa.net/players/209/331/23_60.png   30  ...
#
#     Preferred Foot  Weak Foot Rating  Skill Moves  International Reputation  \
# 4            Right                 4            5                         4
# 21            Left                 3            3                         4
# 42           Right                 3            4                         3
# 82           Right                 4            4                         2
# 5             Left                 3            4                         4
#
#    National Team Name             National Team Image Link  \
# 4              France  https://cdn.sofifa.net/flags/fr.png
# 21             Norway  https://cdn.sofifa.net/flags/no.png
# 42        Netherlands  https://cdn.sofifa.net/flags/nl.png
# 82              Spain  https://cdn.sofifa.net/flags/es.png
# 5                   -                                    -
#
#     National Team Position National Team Jersey Number Attacking Work Rate  \
# 4                       ST                          10                High
# 21                      ST                           9                High
# 42                     CDM                          21                High
# 82                      CM                          10                High
# 5                        -                           -                High
#
#    Defensive Work Rate
# 4                  Low
# 21              Medium
# 42              Medium
# 82                High
# 5               Medium
#
# [5 rows x 32 columns]

# %% [markdown]
# <font size = "5">
#
# (d) Create a function with four inputs $f(y,x,b0,b1)$
#
# <font size = "3">
#
# $\qquad e2 = (y - b_0 - b_1 * x)^2$
#
# - The function should return the sum of e2 entries
# - This is the residual sum of squares (rss)
# - Call the function "fn_rss"
# - Let $y$ be the column "Overall" (overall score)
# - Let $x$ be the column "Age"
# - Does <br>
# $\qquad (b_0 = 50, b_1 = -6 )$ or <br>
# $\qquad (b_0 = 50, b_1 = 0.6 )$ or <br>
# $\qquad (b_0 = 50, b_1 = 6)$ <br>
# produce the lowest value of rss?

# %%
# Write your own code
dataset = pd.DataFrame([])
b0 = 50
b1 = -6

dataset["y"] = fifa23[["Overall"]]
dataset["x"] = fifa23[["Age"]]

fn_rss = (dataset["y"] - b0 - b1 * dataset["x"])**2

display(fn_rss)

dataset = pd.DataFrame([])
b0 = 50
b1 = -0.6

dataset["y"] = fifa23[["Overall"]]
dataset["x"] = fifa23[["Age"]]

fn_rss = (dataset["y"] - b0 - b1 * dataset["x"])**2

display(fn_rss)

dataset = pd.DataFrame([])
b0 = 50
b1 = 6

dataset["y"] = fifa23[["Overall"]]
dataset["x"] = fifa23[["Age"]]

fn_rss = (dataset["y"] - b0 - b1 * dataset["x"])**2

display(fn_rss)
# Out:
# 0        63001
# 1        60025
# 2        57121
# 3        51529
# 4        32041
#          ...
# 18534    15129
# 18535     9801
# 18536    11025
# 18537     9801
# 18538    21609
# Length: 18539, dtype: int64
# 0        3844.00
# 1        3769.96
# 2        3696.64
# 3        3552.16
# 4        3003.04
#           ...
# 18534      92.16
# 18535      51.84
# 18536      60.84
# 18537      51.84
# 18538     144.00
# Length: 18539, dtype: float64
# 0        28561
# 1        26569
# 2        24649
# 3        21025
# 4         9409
#          ...
# 18534    16641
# 18535    11025
# 18536    12321
# 18537    11025
# 18538    23409
# Length: 18539, dtype: int64

# %% [markdown]
# b0 = 50 and b1 = 0.6 produces the lowest value of rss

# %% [markdown]
# <font size = "5">
#
# (e) Split a dataset into subsets
#
# <font size = "3">
#
# - Create ``` list_status = [1,2]```
# - Create ``` list_prob = [0.5, 0.5]```
# - Create a new variable $n$ with the number of rows of the dataset
# - Use
# ```python
#     np.random.choice(list_status,
#                      size = n,
#                      p = list_prob)
# ```
# $\qquad$ to create a new column called "status" <br>
# $\qquad$ which randomly assigns each row to "1" or "2" <br>
# $\qquad$ with equal probability
# - Use .query() to subset all observations with status == 1.<br>
# store it in a new dataset called "data1"
# - Use .query() to subset all observations with status == 2.<br>
# store it in a new dataset called "data2"

# %%
# Write your own code

list_status = [1,2]
list_prob = [0.5, 0.5]
n = 18539
fifa23["status"] = np.random.choice(list_status, size = n, p = list_prob)
data1 = fifa23.query('status == 1 ')
data2 = fifa23.query('status == 2 ')

display(data1.describe())
# Out:
#            Overall    Potential  Value(in Euro)          Age  Height(in cm)  \
# count  9209.000000  9209.000000    9.209000e+03  9209.000000    9209.000000
# mean     65.957867    71.092518    2.977239e+06    25.294386     181.564122
# std       6.835822     6.188899    8.120233e+06     4.771255       6.861690
# min      47.000000    48.000000    0.000000e+00    16.000000     155.000000
# 25%      62.000000    67.000000    5.000000e+05    22.000000     177.000000
# 50%      66.000000    71.000000    1.000000e+06    25.000000     182.000000
# 75%      70.000000    75.000000    2.000000e+06    29.000000     186.000000
# max      91.000000    95.000000    1.905000e+08    44.000000     206.000000
#
#        Weight(in kg)   TotalStats    BaseStats  Wage(in Euro)  Release Clause  \
# count    9209.000000  9209.000000  9209.000000    9209.000000    9.209000e+03
# mean       75.233033  1603.645781   358.147899    9035.150396    5.289607e+06
# std         7.068041   273.055950    39.919326   20212.984443    1.561365e+07
# min        49.000000   762.000000   224.000000       0.000000    0.000000e+00
# 25%        70.000000  1471.000000   331.000000    1000.000000    6.840000e+05
# 50%        75.000000  1643.000000   359.000000    3000.000000    1.500000e+06
# 75%        80.000000  1787.000000   385.000000    8000.000000    3.400000e+06
# max       105.000000  2312.000000   502.000000  420000.000000    3.667000e+08
#
#          Joined On  Weak Foot Rating  Skill Moves  International Reputation  \
# count  9209.000000       9209.000000  9209.000000               9209.000000
# mean   2020.380280          2.953415     2.367249                  1.091432
# std       2.064297          0.676897     0.773837                  0.376177
# min    2002.000000          1.000000     1.000000                  1.000000
# 25%    2020.000000          3.000000     2.000000                  1.000000
# 50%    2021.000000          3.000000     2.000000                  1.000000
# 75%    2022.000000          3.000000     3.000000                  1.000000
# max    2022.000000          5.000000     5.000000                  5.000000
#
#        status
# count  9209.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping histogram plots
#
# <font size = "3">
#
# - This function requires the two datasets you created in (e)
# - Display the distribution of "Potential" for "data1" and "data2"
# - Use the "alpha" option to make the graphs semitransparent
# - You will need to add a legend, label the axes, and the title
#
# Note: The goal of this question is to illustrate that random <br>
# assignment produces very similar distributions between two groups

# %%
# Write your own code

list_data = [data1,data2]


for category in list_data:
    df   = fifa23.query(" Potential == @category")
    plt.hist(x = df["Potential"], alpha = 0.5)
    
   
plt.xlabel("Potential")
plt.ylabel("Frequency")
plt.legend(labels = list_data,
           title  = "Distribution of Potential for Data1 and Data2")
plt.show()
# Out:
# /var/folders/x5/5y001nkn32s3y1kfs5nr9r_00000gn/T/ipykernel_10570/2636839258.py:7: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df   = fifa23.query(" Potential == @category")
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axes/_axes.py:6715: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axes/_axes.py:6716: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 8
#       6 for category in list_data:
#       7     df   = fifa23.query(" Potential == @category")
# ----> 8     plt.hist(x = df["Potential"], alpha = 0.5)
#      11 plt.xlabel("Potential")
#      12 plt.ylabel("Frequency")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/pyplot.py:2581, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2575 @_copy_docstring_and_deprecators(Axes.hist)
#    2576 def hist(
#    2577         x, bins=None, range=None, density=False, weights=None,
#    2578         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2579         orientation='vertical', rwidth=None, log=False, color=None,
#    2580         label=None, stacked=False, *, data=None, **kwargs):
# -> 2581     return gca().hist(
#    2582         x, bins=bins, range=range, density=density, weights=weights,
#    2583         cumulative=cumulative, bottom=bottom, histtype=histtype,
#    2584         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2585         color=color, label=label, stacked=stacked,
#    2586         **({"data": data} if data is not None else {}), **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/__init__.py:1433, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1430 @functools.wraps(func)
#    1431 def inner(ax, *args, data=None, **kwargs):
#    1432     if data is None:
# -> 1433         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1435     bound = new_sig.bind(ax, *args, **kwargs)
#    1436     auto_label = (bound.arguments.get(label_namer)
#    1437                   or bound.kwargs.get(label_namer))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axes/_axes.py:6743, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6739 # Loop through datasets
#    6740 for i in range(nx):
#    6741     # this will automatically overwrite bins,
#    6742     # so that each histogram uses the same bins
# -> 6743     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6744     tops.append(m)
#    6745 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File <__array_function__ internals>:200, in histogram(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/lib/histograms.py:780, in histogram(a, bins, range, density, weights)
#     680 r"""
#     681 Compute the histogram of a dataset.
#     682
#    (...)
#     776
#     777 """
#     778 a, weights = _ravel_and_check_weights(a, weights)
# --> 780 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     782 # Histogram is an integer or a float array depending on the weights.
#     783 if weights is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/lib/histograms.py:426, in _get_bin_edges(a, bins, range, weights)
#     423     if n_equal_bins < 1:
#     424         raise ValueError('`bins` must be positive, when an integer')
# --> 426     first_edge, last_edge = _get_outer_edges(a, range)
#     428 elif np.ndim(bins) == 1:
#     429     bin_edges = np.asarray(bins)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/lib/histograms.py:323, in _get_outer_edges(a, range)
#     321     first_edge, last_edge = a.min(), a.max()
#     322     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 323         raise ValueError(
#     324             "autodetected range of [{}, {}] is not finite".format(first_edge, last_edge))
#     326 # expand empty range to avoid divide by zero
#     327 if first_edge == last_edge:
#
# ValueError: autodetected range of [nan, nan] is not finite
